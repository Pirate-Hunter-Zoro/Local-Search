# %% [markdown]
# ## This code starts off with defining helper functions and graphical functions to display. My own code for Simulated Annealing and Genetic Algorithms comes later in this notebook. All cells complete in under 10 minutes on my Apple M2 Chip Computer, though it usually takes less than 5 minutes. To be honest I don't know why the time varies...

# %%
import numpy as np
import numpy.random as npr
import itertools

_norm = lambda x: np.linalg.norm(x, 1)**2
_inf_norm = lambda x: np.max(x**2)

# %%
# Langermann Parameters
def rand_a(num_points=30, num_dims=10):
    return npr.rand(num_points, num_dims) * 10

def rand_c(num_points=10):
    return npr.rand(num_points)

sample_a = np.array([
    [9.681, 0.667, 4.783, 9.095, 3.517, 9.325, 6.544, 0.211, 5.122, 2.020],
    [9.400, 2.041, 3.788, 7.931, 2.882, 2.672, 3.568, 1.284, 7.033, 7.374],
    [8.025, 9.152, 5.114, 7.621, 4.564, 4.711, 2.996, 6.126, 0.734, 4.982],
    [2.196, 0.415, 5.649, 6.979, 9.510, 9.166, 6.304, 6.054, 9.377, 1.426],
    [8.074, 8.777, 3.467, 1.863, 6.708, 6.349, 4.534, 0.276, 7.633, 1.567],
    [7.650, 5.658, 0.720, 2.764, 3.278, 5.283, 7.474, 6.274, 1.409, 8.208],
    [1.256, 3.605, 8.623, 6.905, 0.584, 8.133, 6.071, 6.888, 4.187, 5.448],
    [8.314, 2.261, 4.224, 1.781, 4.124, 0.932, 8.129, 8.658, 1.208, 5.762],
    [0.226, 8.858, 1.420, 0.945, 1.622, 4.698, 6.228, 9.096, 0.972, 7.637],
    [7.305, 2.228, 1.242, 5.928, 9.133, 1.826, 4.060, 5.204, 8.713, 8.247],
    [0.652, 7.027, 0.508, 4.876, 8.807, 4.632, 5.808, 6.937, 3.291, 7.016],
    [2.699, 3.516, 5.874, 4.119, 4.461, 7.496, 8.817, 0.690, 6.593, 9.789],
    [8.327, 3.897, 2.017, 9.570, 9.825, 1.150, 1.395, 3.885, 6.354, 0.109],
    [2.132, 7.006, 7.136, 2.641, 1.882, 5.943, 7.273, 7.691, 2.880, 0.564],
    [4.707, 5.579, 4.080, 0.581, 9.698, 8.542, 8.077, 8.515, 9.231, 4.670],
    [8.304, 7.559, 8.567, 0.322, 7.128, 8.392, 1.472, 8.524, 2.277, 7.826],
    [8.632, 4.409, 4.832, 5.768, 7.050, 6.715, 1.711, 4.323, 4.405, 4.591],
    [4.887, 9.112, 0.170, 8.967, 9.693, 9.867, 7.508, 7.770, 8.382, 6.740],
    [2.440, 6.686, 4.299, 1.007, 7.008, 1.427, 9.398, 8.480, 9.950, 1.675],
    [6.306, 8.583, 6.084, 1.138, 4.350, 3.134, 7.853, 6.061, 7.457, 2.258],
    [0.652, 2.343, 1.370, 0.821, 1.310, 1.063, 0.689, 8.819, 8.833, 9.070],
    [5.558, 1.272, 5.756, 9.857, 2.279, 2.764, 1.284, 1.677, 1.244, 1.234],
    [3.352, 7.549, 9.817, 9.437, 8.687, 4.167, 2.570, 6.540, 0.228, 0.027],
    [8.798, 0.880, 2.370, 0.168, 1.701, 3.680, 1.231, 2.390, 2.499, 0.064],
    [1.460, 8.057, 1.336, 7.217, 7.914, 3.615, 9.981, 9.198, 5.292, 1.224],
    [0.432, 8.645, 8.774, 0.249, 8.081, 7.461, 4.416, 0.652, 4.002, 4.644],
    [0.679, 2.800, 5.523, 3.049, 2.968, 7.225, 6.730, 4.199, 9.614, 9.229],
    [4.263, 1.074, 7.286, 5.599, 8.291, 5.200, 9.214, 8.272, 4.398, 4.506],
    [9.496, 4.830, 3.150, 8.270, 5.079, 1.231, 5.731, 9.494, 1.883, 9.732],
    [4.138, 2.562, 2.532, 9.661, 5.611, 5.500, 6.886, 2.341, 9.699, 6.500]
])


sample_c = np.array([
    0.806,
    0.517,
    0.1,
    0.908,
    0.965,
    0.669,
    0.524,
    0.902,
    0.531,
    0.876,
    0.462,
    0.491,
    0.463,
    0.714,
    0.352,
    0.869,
    0.813,
    0.811,
    0.828,
    0.964,
    0.789,
    0.360,
    0.369,
    0.992,
    0.332,
    0.817,
    0.632,
    0.883,
    0.608,
    0.326
])

# %%
# Shekel Parameters
def rand_holes(num_holes=30, num_dims=10):
    return npr.rand(num_holes, num_dims) * 10

def rand_weights(num_holes=10):
    return npr.rand(num_holes)

sample_holes = np.array([
    [9.681, 0.667, 4.783, 9.095, 3.517, 9.325, 6.544, 0.211, 5.122, 2.020],
    [9.400, 2.041, 3.788, 7.931, 2.882, 2.672, 3.568, 1.284, 7.033, 7.374],
    [8.025, 9.152, 5.114, 7.621, 4.564, 4.711, 2.996, 6.126, 0.734, 4.982],
    [2.196, 0.415, 5.649, 6.979, 9.510, 9.166, 6.304, 6.054, 9.377, 1.426],
    [8.074, 8.777, 3.467, 1.863, 6.708, 6.349, 4.534, 0.276, 7.633, 1.567],
    [7.650, 5.658, 0.720, 2.764, 3.278, 5.283, 7.474, 6.274, 1.409, 8.208],
    [1.256, 3.605, 8.623, 6.905, 0.584, 8.133, 6.071, 6.888, 4.187, 5.448],
    [8.314, 2.261, 4.224, 1.781, 4.124, 0.932, 8.129, 8.658, 1.208, 5.762],
    [0.226, 8.858, 1.420, 0.945, 1.622, 4.698, 6.228, 9.096, 0.972, 7.637],
    [7.305, 2.228, 1.242, 5.928, 9.133, 1.826, 4.060, 5.204, 8.713, 8.247],
    [0.652, 7.027, 0.508, 4.876, 8.807, 4.632, 5.808, 6.937, 3.291, 7.016],
    [2.699, 3.516, 5.874, 4.119, 4.461, 7.496, 8.817, 0.690, 6.593, 9.789],
    [8.327, 3.897, 2.017, 9.570, 9.825, 1.150, 1.395, 3.885, 6.354, 0.109],
    [2.132, 7.006, 7.136, 2.641, 1.882, 5.943, 7.273, 7.691, 2.880, 0.564],
    [4.707, 5.579, 4.080, 0.581, 9.698, 8.542, 8.077, 8.515, 9.231, 4.670],
    [8.304, 7.559, 8.567, 0.322, 7.128, 8.392, 1.472, 8.524, 2.277, 7.826],
    [8.632, 4.409, 4.832, 5.768, 7.050, 6.715, 1.711, 4.323, 4.405, 4.591],
    [4.887, 9.112, 0.170, 8.967, 9.693, 9.867, 7.508, 7.770, 8.382, 6.740],
    [2.440, 6.686, 4.299, 1.007, 7.008, 1.427, 9.398, 8.480, 9.950, 1.675],
    [6.306, 8.583, 6.084, 1.138, 4.350, 3.134, 7.853, 6.061, 7.457, 2.258],
    [0.652, 2.343, 1.370, 0.821, 1.310, 1.063, 0.689, 8.819, 8.833, 9.070],
    [5.558, 1.272, 5.756, 9.857, 2.279, 2.764, 1.284, 1.677, 1.244, 1.234],
    [3.352, 7.549, 9.817, 9.437, 8.687, 4.167, 2.570, 6.540, 0.228, 0.027],
    [8.798, 0.880, 2.370, 0.168, 1.701, 3.680, 1.231, 2.390, 2.499, 0.064],
    [1.460, 8.057, 1.336, 7.217, 7.914, 3.615, 9.981, 9.198, 5.292, 1.224],
    [0.432, 8.645, 8.774, 0.249, 8.081, 7.461, 4.416, 0.652, 4.002, 4.644],
    [0.679, 2.800, 5.523, 3.049, 2.968, 7.225, 6.730, 4.199, 9.614, 9.229],
    [4.263, 1.074, 7.286, 5.599, 8.291, 5.200, 9.214, 8.272, 4.398, 4.506],
    [9.496, 4.830, 3.150, 8.270, 5.079, 1.231, 5.731, 9.494, 1.883, 9.732],
    [4.138, 2.562, 2.532, 9.661, 5.611, 5.500, 6.886, 2.341, 9.699, 6.500]
])

sample_weights = np.array([
    0.806,
    0.517,
    0.1,
    0.908,
    0.965,
    0.669,
    0.524,
    0.902,
    0.531,
    0.876,
    0.462,
    0.491,
    0.463,
    0.714,
    0.352,
    0.869,
    0.813,
    0.811,
    0.828,
    0.964,
    0.789,
    0.360,
    0.369,
    0.992,
    0.332,
    0.817,
    0.632,
    0.883,
    0.608,
    0.326
])

# %%
# Helpful function
import struct


def bitstr2float(s):
    """Transforms a bit representation of a number between 0 and 1 to a
    floating point number. This is less error-prone (I believe) than
    something like float division.

    Additionally, if len(s) < 52, this method will choose the midpoint
    between two decimal values to guaratee that each value is equally
    displaced.

    :param str s: A string formatted as a bitstring
    """
    if len(s) < 52:
        s = s + ("1" + "0" * (51 - len(s)))
    elif len(s) > 52:
        raise ValueError("Bitstring cannot be longer than 52 bits (floating point number limit).")
    # https://stackoverflow.com/a/8751666
    b = '0b001111111111{}'.format(s)
    return struct.unpack('d', struct.pack('Q', int(b, 0)))[0] - 1

# %%
def sphere(x):
    """
    The sphere model. A basic function, where the minimum is at (1,1).

    Range: x_i in [-5, 5]

    :param numpy.ndarray x: The input vector
    """
    return _norm(x - 1.0)

def sphere_c(x):
    return np.all(np.logical_and(
        x >= -5,
        x <= 5
    ))

# %%
def griew(x, D=4000.0):
    """
    Griewank's function. Similar to the sphere function, but much
    noisier around each point. The obvious minimum is at (100,100).

    Range: x_i in [0, 200]

    :param numpy.ndarray x: The input vector
    """
    n = len(x)
    term1 = _norm(x - 100) / D
    term2 = np.prod(np.cos((x-100) / np.sqrt(np.arange(n)+1)))
    return term1 - term2 + 1.0

def griew_c(x):
    return True

# %%
def shekel(x, holes=sample_holes, weights=sample_weights):
    """
    Modified Shekel's Foxholes. The function is mostly uniform, except
    for points very close to each "foxhole," in which the function
    dramatically decreases.

    Range: x_i in [0, 10]

    :param numpy.ndarray x: The (n x 1) input vector
    :param numpy.ndarray holes: An (n x m) matrix, consisting of m (n x 1) holes
    :param numpy.ndarray weights: A (m x 1) vector specifying the depth of each hole
    """
    n = len(x)
    m = holes.shape[0]
    if n > holes.shape[1]:
        raise ValueError(
            "Dimension of x is greater than dimension of holes. ({} > {})"
            .format(n, holes.shape[1])
        )
    return sum([-1.0 / (_norm(x - holes[j,:n] + weights[j])) for j in range(m)])

def shekel_c(x):
    return np.all(np.logical_and(
        x >= 0,
        x <= 10
    ))

# %%
def micha(x, m=10):
    """
    Michalewitz's function. A noisy function with many local minima.

    Range: x_i in [-100, 100]

    :param numpy.ndarray x: The (n x 1) input vector
    :param float m: Parameter that affects the level of variation in the curves
    """
    n = len(x)
    cos_pi_6 = np.cos(np.pi / 6)
    sin_pi_6 = np.sin(np.pi / 6)
    y = np.zeros(n)
    y[::2] = [x1 * cos_pi_6 - x2 * sin_pi_6 for (x1, x2) in zip(x[:-1], x[1:])]
    y[1::2] = [x1 * sin_pi_6 + x2 * cos_pi_6 for (x2, x1) in zip(x[1:], x[:-1])]
    y[n-1] = x[n-1]
    return sum(np.sin(y) * np.sin((np.arange(n) + 1) * y**2 / np.pi)**(2*m))

def micha_c(x):
    ## This works anywhere and couldn't find any constraint
    ## specification. A good choice of range might be (-100, 100) for
    ## any dimension.
    return True

# %%
def langermann(x, a=sample_a, c=sample_c):
    """Langermann's function. Another noisy function, although local maxima/minima are located near points given in the a matrix.

    Range: x_i in [0, 10]

    :param numpy.ndarray x: The (n x 1) input vector
    :param numpy.ndarray a: An (n x m) matrix of m (n x 1) vectors; each specifying a "region of more instability"
    :param numpy.ndarray c: An (m x 1) vector of weights associated with each vector in a.
    """
    n = len(x)
    m = a.shape[0]
    if n > a.shape[1]:
        raise ValueError(
            "Dimension of x is greater than dimension of a. ({} > {})"
            .format(n, a.shape[1])
        )
    term1 = [np.exp(-_norm(x - a[i,:n]) / np.pi) for i in range(m)]
    term2 = [np.cos(np.pi * _norm(x - a[i,:n])) for i in range(m)]
    return sum([c_i * term1_i * term2_i for (c_i, term1_i, term2_i) in zip(c, term1, term2)])

def langermann_c(x):
    return np.all(np.logical_and(
        x >= 0,
        x <= 10
    ))

# %%
default_center_point = np.array([1., 1.3, .8, -.4, -1.3, 1.6, -.2, -.6, .5, 1.4,
                                 1., 1.3, .8, -.4, -1.3, 1.6, -.2, -.6, .5, 1.4])

def odd_square(x, center_point=default_center_point, c=0.2):
    """The Odd Square function. As the function approaches the center
point, it begins to oscillate more and more.

    Range: x_i is in (-5 pi, 5 pi)

    :param numpy.ndarray x: The (n x 1) input vector
    """
    n = len(x)
    dist = _inf_norm(x - center_point[:n])
    term1 = np.exp(-dist / (2 * np.pi))
    term2 = np.cos(np.pi * dist)
    term3 = 1 + c * dist / (dist + 0.01)
    return term1 * term2 * term3

def odd_square_c(x):
    return np.all(np.logical_and(
        x >= -5 * np.pi,
        x <= 5 * np.pi
    ))

# %%
def bump(x):
    """The Bump function. Very smooth, but note that the constraints on
    this function cannot be easily encoded into the chromosonal design
    of the GA.

    Range: x_i is in (0,100)

    :param numpy.ndarray x: The (n x 1) input vector
    """
    n = len(x)
    cos_x = np.cos(x)
    term1 = np.sum(cos_x**4) - 2 * np.prod(cos_x**2)
    term2 = np.sqrt(np.sum(np.multiply(1.0 + np.arange(n), x**2)))
    return abs(term1 / term2)

def bump_c(x):
    ## \prod_{i=1}^n x_i \geq 0.75
    np.prod(x) >= 0.75\
        and np.sum(x) <= 7.5 * len(x)

# %% [markdown]
# # Now we will be implementing local search...

# %%
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt
from matplotlib import cm

class FunctionOptimizer(ABC):
    """We will extend this class in two ways - a Simulated Annealing Solver and Genetic Algorithm Solver
    """

    def __init__(self, x_min: np.array, x_max: np.array):
        """All solvers using some kind of local search will have bounds on their inputs
        """
        self._x_min = x_min
        self._x_max = x_max
        self._max_input = x_min
        self._max_output = float('-inf')

    def function_template(x: np.array) -> float:
        """For book-keeping, just make it known that the types of functions we are expecting to optimize take in numpy arrays and output scalars
        """
        return np.linalg.norm(x)

    @abstractmethod
    def maximize(self, function: type[function_template], ax: plt.Axes = None):
        """Here is where we implement the actual algorithm to maximize a function - which has different specific behaviors depending on class extension
        """
        pass

    def plot_results(self, function: type[function_template], title: str, plot_function: bool=True):
        """Plot the results of this solver as it attempts to maximize the given function
        """
        # Refresh our records
        self._x_min = self._x_min
        self._x_max = self._x_max
        self._max_input = self._x_min
        self._max_output = float('-inf')

        # We are showing the graph
        dx = (self._x_max[0] - self._x_min[0]) / 100
        dy = (self._x_max[1] - self._x_min[1]) / 100
        X, Y = np.mgrid[self._x_min[0]:self._x_max[0]+dx:dx, self._x_min[1]:self._x_max[1]+dx:dy]
        Z = np.zeros(X.shape)
        for i, j in itertools.product(range(X.shape[0]), range(X.shape[1])):
            Z[i, j] = function(np.array([X[i,j], Y[i,j]]))

        # From https://matplotlib.org/stable/gallery/mplot3d/surface3d.html#sphx-glr-gallery-mplot3d-surface3d-py
        fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
        
        # Plot the surface
        if plot_function:
            surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, alpha = 0.2, antialiased=False)
            # Add a color bar which maps values to colors.
            fig.colorbar(surf, shrink=0.5, aspect=5)
        
        # Customize the z axis.
        ax.set_zlim(np.min(Z), np.max(Z))
        # Customize the z axis.
        # A StrMethodFormatter is used automatically
        ax.zaxis.set_major_formatter('{x:.02f}')

        self.maximize(function=function, ax=ax)
        print(f"Highest Achieved: {self._max_input, self._max_output}")

        plt.title(title)
        plt.show()
        plt.close(fig)

# %% [markdown]
# # The code for Simulated Annealing follows...

# %%
from math import exp
from typing import Type
import random
import numpy as np

class SimulatedAnnealingSolver(FunctionOptimizer):
    """Uses the simulated-annealing algorithm with a given scheduling function to estimate a maximum for a function
    """
    
    def __init__(self, schedule_func: Type[FunctionOptimizer.function_template], x_min: np.array, x_max: np.array, tolerance=0.000001):
        """Given a certain time - as an integer - return a temperature float, which determines how likely we are to change positions.
        The schedule function gives a temperature at a given integer input time.
        The tolerance if how close we let the temperature reach 0 before deciding we are done.
        The step_scale decides how massive our random steps are as we attempt to maximize our function
        """
        super().__init__(x_min=x_min, x_max=x_max)
        self.schedule_func = schedule_func
        self.tolerance = tolerance

    def maximize(self, function: type[FunctionOptimizer.function_template], ax: plt.Axes = None):
        """All extensions of FunctionOptimizer must implement this method
        """
        current = (self._x_min + self._x_max) / 2
        t = 0
        while True:
            x, y, stop = self.__take_step(function, current=current, time=t)
            if ax != None:
                ax.scatter3D(x[0], x[1], y, color="red")
            if self._max_output < y:
                self._max_output = np.float64(y)
                self._max_input = x

            if stop:
                break
            t += 1
    
    def __take_step(self, function: type[FunctionOptimizer.function_template], current: np.array, time: int) -> tuple[np.array, float, bool]:
        """This is how our simulated annealing solver takes a step forward
        """
        temperature = self.schedule_func(time)
        if temperature <= self.tolerance:
            return current, function(current), True
        else:
            next = self.__random_step(current)
            delta = function(next) - function(current)
            if delta > 0:
                # If the random change in position resulted in a positive change, we will definitely take the step in that direction
                current = next
                return current, function(current), False
            else:
                # We only have a certain chance of taking it
                prob = exp(delta / temperature)
                if random.random() <= prob:
                    current = next
                return current, function(current), False
    
    def __random_step(self, current: np.array) -> np.array:
        """Take a step away from the input in a random direction
        """
        return current + np.array([(0.5 - random.random())*(self._x_max[0]-self._x_min[0]), (0.5 - random.random())*(self._x_max[1]-self._x_min[1])])

# %% [markdown]
# ### Run the following cells repeatedly to see varying results...

# %%
functions = [sphere, griew, shekel, micha, langermann, odd_square, bump]
titles = ["Sphere Function", "Griew Function", "Shekel Function", "Micha Function", "Langermann Function", "Odd Square Function", "Bump Function"]

# %%
solver = SimulatedAnnealingSolver(lambda n : exp(-n/10), x_min=np.array([1, 1]), x_max=np.array([10, 10]),)

for function, title in zip(functions,titles):
    solver.plot_results(function=function, title=title)
    print("--------------------------------------------------------------")
# Out:
# Highest Achieved: (array([9.52799713, 8.98565049]), np.float64(272.7005576857769))
# --------------------------------------------------------------
# Highest Achieved: (array([2.3374734 , 1.36776026]), np.float64(11.411835836047533))
# --------------------------------------------------------------
# Highest Achieved: (array([9.47704751, 9.37046831]), np.float64(-0.6954016178662017))
# --------------------------------------------------------------
# Highest Achieved: (array([3.3359445 , 1.50902259]), np.float64(1.5922990341325558))
# --------------------------------------------------------------
# Highest Achieved: (array([8.70718376, 4.22849166]), np.float64(1.2626463407475224))
# --------------------------------------------------------------
# Highest Achieved: (array([3.02633294, 1.18589669]), np.float64(0.589719296077511))
# --------------------------------------------------------------
# Highest Achieved: (array([3.02145536, 1.82350698]), np.float64(0.21452137081822992))
# --------------------------------------------------------------

# %% [markdown]
# # The code for Genetic Algorithms follows...

# %%
import numpy as np

class GeneticAlgorithmSolver(FunctionOptimizer):
    """Uses a genetic algorithm to estimate a maximum for a function
    """
    
    def __init__(self, x_min: np.array, x_max: np.array, input_dims: int=2, string_size: int=10, generations: int = 100, num_switches: int = 1):
        """Initialize the parameters for our genetic algorithm, which include string size, and where we split each string when crossing two strings, and the number of generations we want to generate
        """
        # The user could very well input some hyperparameters that make no sense - we'll correct for them here
        super().__init__(x_min=x_min, x_max=x_max)
        self.__input_size = input_dims
        self.__generation_size = 2**string_size # There this many different possible strings, so it is a natural number to decide the population size
        self.__string_size = max(10, string_size)

        # The following is for when parents generate offspring
        self.__num_switch_intervals = min(max(1, num_switches), self.__string_size // 5)
        splits = random.sample(range(0,self.__string_size), 2 * self.__num_switch_intervals)
        splits.sort()
        starts = [splits[i] for i in range(len(splits)) if (i % 2 == 0)]
        ends = [splits[i] for i in range(len(splits)) if (i % 2 == 1)]
        self.__switch_intervals = [[start_incl, end_excl] for start_incl, end_excl in zip(starts, ends)]

        # We have a current generation - that generation can be represented as a bit string (number) for each coordinate in each generation member (which is a vector)
        self.__current_generation = [[self.__random_bit_string() for _ in range(self.__input_size)] for _ in range(self.__generation_size)]
        # We can also store the actual vector
        self.__current_points = [self.__create_vector(bit_strings) for bit_strings in self.__current_generation]

        # How many generations we will produce
        self.__num_generations = generations

    def maximize(self, function: type[FunctionOptimizer.function_template], ax: plt.Axes = None):
        """All extensions of FunctionOptimizer must implement this method
        """
        # We have a current generation - that generation can be represented as a bit string (number) for each coordinate in each generation member (which is a vector)
        self.__current_generation = [[self.__random_bit_string() for _ in range(self.__input_size)] for _ in range(self.__generation_size)]
        # We can also store the actual vector
        self.__current_points = [self.__create_vector(bit_strings) for bit_strings in self.__current_generation]
        
        current_values = [function(x) for x in self.__current_points]
        all_points = self.__current_points
        all_values = current_values
        for i in range(self.__num_generations):
            # The following is to monitor progress
            if (i % (self.__num_generations // 10) == 0):
                print(f"Model is {int(100 * i / self.__num_generations)}% through training...")
            
            current_fitness_sum = sum(current_values)

            # Calculate the fitness of each individual by finding the probability intervals
            curr_sum = 0
            lower_upper = []
            for idx, fitness in enumerate(current_values):
                if fitness > self._max_output:
                    self._max_output = fitness
                    self._max_input = self.__current_points[idx]
                lower = curr_sum / current_fitness_sum
                curr_sum += fitness
                upper = curr_sum / current_fitness_sum
                lower_upper.append((lower, upper))

            # Now we need to select population members to generate the next generation
            parents = []
            for _ in range(self.__generation_size):
                selector = random.random()
                parents.append(self.__current_generation[self.__select_population_member(selector, lower_upper)])
            # Sort the parents by their fitness so that higher fitness parents will be grouped together
            parents.sort(key=lambda bit_strings: function(self.__create_vector(bit_strings=bit_strings)))

            # Given our parent indices, generate their offspring     
            next_generation = []
            mothers = [parents[i] for i in range(len(parents)) if (i % 2 == 0)]
            fathers = [parents[i] for i in range(len(parents)) if (i % 2 == 1)]
            for mother, father in zip(mothers, fathers):
                offspring = self.__reproduce(mother, father)
                next_generation.append(offspring[0])
                next_generation.append(offspring[1])
            self.__current_generation = next_generation

            # Evaluate the next generation's fitness
            self.__current_points = [self.__create_vector(bit_strings) for bit_strings in self.__current_generation]
            current_values = [function(x) for x in self.__current_points]
            for point, val in zip(self.__current_points, current_values):
                all_points.append(point)
                all_values.append(val)
            current_fitness_sum = sum(current_values)

        # Plot all of our points
        X = np.array(all_points)[:, 0]
        Y = np.array(all_points)[:, 1]
        Z = np.array(all_values)
        if ax != None:
            ax.scatter3D(X, Y, Z, color=(0.1, 0.2, 0.5))

    def __select_population_member(self, selector: float, lower_upper: list[tuple[float,float]]) -> int:
        """Use binary search to find the index of the current population member whose selection corresponds with the given float between 0 and 1
        """
        left = 0
        right = len(self.__current_generation)
        while left < right:
            mid = (left + right) // 2
            # We're done when the lower of some element is below or equal to selector, and the upper is above it
            if lower_upper[mid][0] <= selector and lower_upper[mid][1] > selector:
                return mid
            elif lower_upper[mid][0] > selector:
                # Look left
                right = mid
            else:
                # Look right
                left = mid + 1
        # The code should never reach here...
        return left

    def __random_bit_string(self) -> int:
        """Return a random integer between 000..00 and 111..11 (length equal to self.string_size)
        """
        return random.sample(range(0, 2**self.__string_size), 1)[0]
    
    def __create_vector(self, bit_strings: list[int]) -> np.array:
        """Given a list of integers, each representing a bit string corresponding to one coordinate of our input space, generate the resulting vector
        """
        x = np.zeros(self.__input_size)
        for i, bit_string in enumerate(bit_strings):
            min_float = self._x_min[i]
            max_float = self._x_max[i]
            # Scale according to bit_string value versus maximum possible bit_string value
            x[i] += min_float + (max_float-min_float)*bit_string/(2**self.__string_size)
        return x
    
    def __reproduce(self, x_list: list[int], y_list: list[int]) -> tuple[list[int],list[int]]:
        """Given two lists of bit strings (each corresponding to an input array), create two offspring from the two parents which will create two new vectors for the next generation
        """
        first_offspring_vector = []
        second_offspring_vector = []
        for x, y in zip(x_list, y_list):
            # Make sure to pad with zeros
            x_str = bin(x)[2:]
            x_str += '0'*(self.__string_size-len(x_str))
            y_str = bin(y)[2:]
            y_str += '0'*(self.__string_size-len(y_str))
            # Perform the slicing
            x_str_copy = x_str
            y_str_copy = y_str
            for start_end in self.__switch_intervals:
                start = start_end[0]
                end = start_end[1]
                x_str = x_str[:start] + y_str_copy[start:end] + x_str[end:]
                y_str = y_str[:start] + x_str_copy[start:end] + y_str[end:]
            # Now convert back into integers
            first_offspring_vector.append(int(x_str, 2))
            second_offspring_vector.append(int(y_str, 2))
        
        return first_offspring_vector, second_offspring_vector

# %% [markdown]
# ### Once again, run the following cells repeatedly to see varying results...

# %%
solver = GeneticAlgorithmSolver(x_min=np.array([1,1]), x_max=np.array([10,10]))

for function, title in zip(functions, titles):
    solver.plot_results(function=function, title=title)
    print("--------------------------------------------------------------")
# Out:
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([9.96484375, 9.98242188]), np.float64(322.10434341430664))
# --------------------------------------------------------------
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([2.46777344, 2.04589844]), np.float64(11.532576920869602))
# --------------------------------------------------------------
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([9.84179688, 9.859375  ]), np.float64(-0.4573079206836321))
# --------------------------------------------------------------
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([6.98535156, 7.83789062]), np.float64(1.4941718970325146))
# --------------------------------------------------------------
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([8.57617188, 1.01757812]), np.float64(1.6358809137714265))
# --------------------------------------------------------------
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([1.25488281, 1.25488281]), np.float64(1.1371500265494063))
# --------------------------------------------------------------
# Model is 0% through training...
# Model is 10% through training...
# Model is 20% through training...
# Model is 30% through training...
# Model is 40% through training...
# Model is 50% through training...
# Model is 60% through training...
# Model is 70% through training...
# Model is 80% through training...
# Model is 90% through training...
# Highest Achieved: (array([3.11816406, 1.58007812]), np.float64(0.26034537819828957))
# --------------------------------------------------------------
